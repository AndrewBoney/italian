# %% [raw]
# ---
# description: First Lesson; Introductions and basics
# output-file: lesson.html
# title: Lesson 1
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
